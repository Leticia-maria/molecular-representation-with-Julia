# %%
print("Hello, IJulia")
# Out:
# Hello, IJulia

# %%
using Pkg

# %%
Pkg.add("MolecularGraph")
# Out:
#    Updating registry at `~/.julia/registries/General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
#   Resolving package versions...
#    Updating `~/.julia/environments/v1.4/Project.toml`
#  [no changes]
#    Updating `~/.julia/environments/v1.4/Manifest.toml`
#  [no changes]

# %%
using MolecularGraph

# %%
using MolecularGraph.Graph

# %%
cid = "6437877"  # PubChem CID
# Out:
# "6437877"

# %%
name = "Cefditoren Pivoxil"  # FIle name
# Out:
# "Cefditoren Pivoxil"

# %%
data_dir = "_data"
# Out:
# "_data"

# %%
isdir(data_dir) || mkdir(data_dir)
# Out:
# true

# %%
url = "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/$(cid)/SDF"
# Out:
# "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/6437877/SDF"

# %%
dest = joinpath(data_dir, "$(name).mol")
# Out:
# "_data/Cefditoren Pivoxil.mol"

# %%
isfile(dest) || download(url, dest);

# %%
mol = sdftomol(joinpath(data_dir, "Cefditoren Pivoxil.mol"))
# Out:
# GraphMol{SDFileAtom,SDFileBond}([Dict(2 => 21,1 => 17), Dict(4 => 40,3 => 30), Dict(5 => 37,6 => 39), Dict(7 => 19), Dict(9 => 28,8 => 23), Dict(10 => 23), Dict(11 => 25), Dict(13 => 32,12 => 28), Dict(14 => 13,15 => 41), Dict(16 => 32)  …  Dict(65 => 37), Dict(66 => 38), Dict(67 => 38), Dict(68 => 38), Dict(69 => 40), Dict(70 => 41), Dict(71 => 41), Dict(72 => 41), Dict(29 => 16), Dict(30 => 16)], [(1, 17), (1, 21), (2, 30), (2, 40), (3, 37), (3, 39), (4, 19), (5, 23), (5, 28), (6, 23)  …  (35, 59), (36, 38), (37, 60), (38, 61), (38, 62), (38, 63), (40, 64), (41, 65), (41, 66), (41, 67)], SDFileAtom[SDFileAtom(:S, 0, 1, nothing, [6.3582, -2.257, 0.0], :unspecified), SDFileAtom(:S, 0, 1, nothing, [4.5691, -2.3448, 0.0], :unspecified), SDFileAtom(:S, 0, 1, nothing, [13.1923, -2.7526, 0.0], :unspecified), SDFileAtom(:O, 0, 1, nothing, [8.9381, -0.0443, 0.0], :unspecified), SDFileAtom(:O, 0, 1, nothing, [7.2242, 1.243, 0.0], :unspecified), SDFileAtom(:O, 0, 1, nothing, [5.4921, 1.243, 0.0], :unspecified), SDFileAtom(:O, 0, 1, nothing, [10.1654, -1.2475, 0.0], :unspecified), SDFileAtom(:O, 0, 1, nothing, [8.0902, 2.743, 0.0], :unspecified), SDFileAtom(:O, 0, 1, nothing, [9.383, -4.1436, 0.0], :unspecified), SDFileAtom(:O, 0, 1, nothing, [7.2242, 4.243, 0.0], :unspecified)  …  SDFileAtom(:H, 0, 1, nothing, [12.3188, -3.9146, 0.0], :unspecified), SDFileAtom(:H, 0, 1, nothing, [2.1916, -1.4461, 0.0], :unspecified), SDFileAtom(:H, 0, 1, nothing, [1.4103, -1.8442, 0.0], :unspecified), SDFileAtom(:H, 0, 1, nothing, [1.8084, -2.6254, 0.0], :unspecified), SDFileAtom(:H, 0, 1, nothing, [4.6245, -3.7974, 0.0], :unspecified), SDFileAtom(:H, 0, 1, nothing, [8.5236, -4.9473, 0.0], :unspecified), SDFileAtom(:H, 0, 1, nothing, [8.9604, -5.7076, 0.0], :unspecified), SDFileAtom(:H, 0, 1, nothing, [9.7207, -5.2707, 0.0], :unspecified), SDFileAtom(:H, 0, 1, nothing, [14.1786, -1.1085, 0.0], :unspecified), SDFileAtom(:H, 0, 1, nothing, [13.3454, -0.431, 0.0], :unspecified)], SDFileBond[SDFileBond(1, 0, :unspecified), SDFileBond(1, 0, :unspecified), SDFileBond(1, 0, :unspecified), SDFileBond(1, 0, :unspecified), SDFileBond(1, 0, :unspecified), SDFileBond(1, 0, :unspecified), SDFileBond(2, 0, :unspecified), SDFileBond(1, 0, :unspecified), SDFileBond(1, 0, :unspecified), SDFileBond(2, 0, :unspecified)  …  SDFileBond(1, 0, :unspecified), SDFileBond(1, 0, :unspecified), SDFileBond(1, 0, :unspecified), SDFileBond(1, 0, :unspecified), SDFileBond(1, 0, :unspecified), SDFileBond(1, 0, :unspecified), SDFileBond(1, 0, :unspecified), SDFileBond(1, 0, :unspecified), SDFileBond(1, 0, :unspecified), SDFileBond(1, 0, :unspecified)], Dict{Symbol,Any}(), Dict{Symbol,Any}(:PUBCHEM_IUPAC_INCHIKEY => "AFZFFLVORLEPPO-UVYJNCLZSA-N",:PUBCHEM_XLOGP3 => "4.7",:PUBCHEM_BOND_UDEF_STEREO_COUNT => "0",:PUBCHEM_MONOISOTOPIC_WEIGHT => "620.11816077",:PUBCHEM_MOLECULAR_FORMULA => "C25H28N6O7S3",:PUBCHEM_TOTAL_CHARGE => "0",:PUBCHEM_IUPAC_CAS_NAME => "(6R,7R)-7-[[(2Z)-2-(2-amino-4-thiazolyl)-2-methoxyimino-1-oxoethyl]amino]-3-[(Z)-2-(4-methyl-5-thiazolyl)ethenyl]-8-oxo-5-thia-1-azabicyclo[4.2.0]oct-2-ene-2-carboxylic acid (2,2-dimethyl-1-oxopropoxy)methyl ester",:PUBCHEM_IUPAC_NAME_MARKUP => "2,2-dimethylpropanoyloxymethyl (6<I>R</I>,7<I>R</I>)-7-[[(2<I>Z</I>)-2-(2-amino-1,3-thiazol-4-yl)-2-methoxyiminoacetyl]amino]-3-[(<I>Z</I>)-2-(4-methyl-1,3-thiazol-5-yl)ethenyl]-8-oxo-5-thia-1-azabicyclo[4.2.0]oct-2-ene-2-carboxylate",:PUBCHEM_CACTVS_HBOND_DONOR => "2",:PUBCHEM_MOLECULAR_WEIGHT => "620.7"…))

# %%
molsvg = drawsvg(mol, 300, 300)
# Out:
# "<svg xmlns=\"http://www.w3.org/2000/svg\"\n xmlns:xlink=\"http://www.w3.org/1999/xlink\"\n version=\"1.2\" baseProfile=\"tiny\"\n text-rendering=\"geometricPrecision\"\n preserveAspectRatio=\"xMidYMid meet\"\n font-weight=\"normal\"\n font-family=\"Helvetica\"\n width=\"300\" height=\"300\"\n viewBox=\"0 0 443.06 400.62\">\n<rect x=\"0\" y=\"0\" width=\"443.06\" height=\"400.62\"\n fill=\"rgb(255, 255, 255)\" opacity=\"0.0\"/>\n<line x1=\"392.70\" y1=\"224.48\" x2=\"391.38\" y2=\"221.00\" stroke=\"rgb(0, 0, 255)\" />\n<line x1=\"391.38\" y1=\"221.00\" x2=\"390.05\" y2=\"217.53\" stroke=\"rgb(0, 0, 0)\" />\n<line x1=\"204.42\" y1=\"132.09\" x2=\"199.97\" y2=\"119.86\" stroke=\"rgb(0, 0, 0)\" /><line x1=\"335.00\" y1=\"279.32\" x2=\"358.27\" y2=\"298.25\" stroke=\"rgb(0, 0, 0)\" /><line x1=\"340.17\" y1=\"277.72\" x2=\"358.78\" y2=\"292.87\" stroke=\"rgb(0, 0, 0)\" /><g stroke=\"rgb(0, 0, 0)\" stroke-width=\"0.3\" transform=\"matrix(0.65 2.46 -0.37 0.10 204.42 252.09)\">\n <line x1=\"0\" y1=\"1\" x2=\"0\" y2=\"-1\" />\n <line x1=\"1\" y1=\"2\" x2=\"1\" y2=\"-2\" />\n <line x1=\"2\" y1=\"3\" x2=\"2\" y2=\"-3\" />\n <line x1=\"3\" y1=\"4\" x2=\"3\" y2=\"-4\" />\n <line x1=\"4\" y1=\"5\" x2=\"4\" y2=\"-5\" />\n <line x1=\"5\" y1=\"6\" x2=\"5\" y2=\"-6\" />\n <line x1=\"6\" y1=\"7\" x2=\"6\" y2=\"-7\" />\n <line x1=\"7\" y1=\"8\" x2=\"7\" y2=\"-8\" />\n</g>\n<line x1=\"256.38\" y1=\"72.09\" x2=\"282.36\" y2=\"57.09\" stroke=\"rgb(0, 0, 0)\" /><line x1=\